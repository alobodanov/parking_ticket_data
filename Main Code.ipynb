# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import json
import numpy as np
import re

# %%
csv_tickets_1 = "Resources/parking_tickets_2015/Parking_Tags_Data_2015_1.csv"
ticket_df_1 = pd.read_csv(csv_tickets_1)
#ticket_df_1["date_of_infraction"] = ticket_df_1["date_of_infraction"].astype(int)
ticket_df_1.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***87325            20150101               15
# 1          ***87326            20150101               15
# 2          ***09493            20150101                3
# 3          ***67358            20150101                5
# 4          ***87327            20150101                5
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0  PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 1  PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 2        PARK ON PRIVATE PROPERTY               30                 2.0
# 3  PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# 4  PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
#
#   location1      location2 location3   location4 province
# 0       OPP  11 CENTRE AVE       NaN         NaN       ON
# 1       OPP  11 CENTRE AVE       NaN         NaN       ON
# 2        NR   2425 JANE ST       NaN         NaN       ON
# 3       N/S      DUNDAS SQ       E/O    YONGE ST       ON
# 4       N/S     ARMOURY ST       W/O  CENTRE AVE       ON

# %%
csv_tickets_2 = "Resources/parking_tickets_2015/Parking_Tags_Data_2015_2.csv"
ticket_df_2 = pd.read_csv(csv_tickets_2)
ticket_df_2.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***26271            20150510               29
# 1          ***47587            20150510               29
# 2          ***95886            20150510                3
# 3          ***60513            20150510                2
# 4          ***00993            20150510                8
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0  PARK PROHIBITED TIME NO PERMIT               30               219.0
# 1  PARK PROHIBITED TIME NO PERMIT               30               219.0
# 2        PARK ON PRIVATE PROPERTY               30               220.0
# 3     PARK - LONGER THAN 3 HOURS                15               220.0
# 4    STAND VEH.-PROHIBIT TIME/DAY               60               220.0
#
#   location1          location2 location3 location4 province
# 0        NR    21 CLAXTON BLVD       NaN       NaN       ON
# 1        NR   209 FAIRVIEW AVE       NaN       NaN       ON
# 2        AT     24 MABELLE AVE       NaN       NaN       ON
# 3        NR      18 LINDEN AVE       NaN       NaN       ON
# 4        NR  364 ADELAIDE ST W       NaN       NaN       ON

# %%
csv_tickets_3 = "Resources/parking_tickets_2015/Parking_Tags_Data_2015_3.csv"
ticket_df_3 = pd.read_csv(csv_tickets_3)
ticket_df_3.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***98714            20150911              210
# 1          ***03276            20150911              403
# 2          ***06931            20150911                2
# 3          ***78878            20150911               29
# 4          ***01730            20150911              210
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0    PARK FAIL TO DISPLAY RECEIPT               30              1707.0
# 1   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1707.0
# 2     PARK - LONGER THAN 3 HOURS                15              1707.0
# 3  PARK PROHIBITED TIME NO PERMIT               30              1707.0
# 4    PARK FAIL TO DISPLAY RECEIPT               30              1707.0
#
#   location1           location2 location3 location4 province
# 0        NR  151 DAN LECKIE WAY       NaN       NaN       ON
# 1        NR   2143 DANFORTH AVE       NaN       NaN       ON
# 2        NR      90 BURNSIDE DR       NaN       NaN       ON
# 3        NR        41 DALTON RD       NaN       NaN       ON
# 4        NR     10 ELLERBECK ST       NaN       NaN       ON

# %%
tickets_2015_df=pd.concat([ticket_df_1,ticket_df_2,ticket_df_3])
locations = list(tickets_2015_df["location2"])
# Out:
# ['7 ROCHEFORT DR', '167 DAVID DUNLAP CRCL', '29 BELLHAVEN RD', '91 BURNDALE AVE', '4675 STEELES AVE E', '4675 STEELES AVE E', '7 ROCHEFORT DR', 'FRITH RD', '161 DAVID DUNLAP CRCL', '170 BEECH AVE', '91 BURNDALE AVE', '4675 STEELES AVE E', '4675 STEELES AVE E', '4675 STEELES AVE E', '4675 STEELES AVE E', '11 ROCHEFORT DR', 'FRITH RD', '193 BEECH AVE', '4675 STEELES AVE E', '11 ROCHEFORT DR', 'FRITH RD', '120 DUNDALK DR', '30 NORCROSS RD', '69 BURNETT AVE', '4675 STEELES AVE E', '4675 STEELES AVE E', '4675 STEELES AVE E', '24 FERRAND DR', '700 HUMBERWOOD BLVD', '310 NISKA RD', '28 NORCROSS RD', '66 BURNETT AVE', '310 NISKA RD', 'BEECH AVE', '120 DUNDALK DR', '88 HIGHCROFT RD', '4675 STEELES AVE E', '55 FERRAND DR', '33 SINGER CRT', '310 NISKA RD', '700 HUMBERWOOD BLVD', '120 DUNDALK DR', '33 SINGER CRT', '50 ROCHEFORT DR', '310 NISKA RD', '11 HUMPHREY GT', '33 SINGER CRT', '50 ROCHEFORT DR', '310 NISKA RD', '310 NISKA RD', '6 UNDERHILL DR', '304 KINGSWOOD RD', '700 HUMBERWOOD BLVD', '120 DUNDALK DR', '33 SINGER CRT', '152 ALMORE AVE', '50 ROCHEFORT DR', '310 NISKA RD', '10 ROANOKE RD', '700 HUMBERWOOD BLVD', '75 PROVOST DR', '152 ALMORE AVE', '193 SHAW ST', '50 ROCHEFORT DR', '310 NISKA RD', '10 ROANOKE RD', '700 HUMBERWOOD BLVD', '87 GAINSBOROUGH RD', '43 FREELAND ST', '39 NIAGARA ST', '21 POTSDAM RD', '310 NISKA RD', '10 ROANOKE RD', '10 ROANOKE RD', '426 KINGSWOOD RD', '700 HUMBERWOOD BLVD', '700 HUMBERWOOD BLVD', '39 NIAGARA ST', '21 POTSDAM RD', '82 MAITLAND ST', 'JOHN ST', '60 HEMLOCK AVE', '128 CLANTON PARK RD', '43 FREELAND ST', '21 POTSDAM RD', '700 HUMBERWOOD BLVD', '10 ROANOKE RD', '201 CARLAW AVE', 'DENGATE RD', nan, '19 PROVINCETOWN RD', '126 CLANTON PARK RD', 'CARIBOU RD', '10 ROANOKE RD', '201 CARLAW AVE', '2 COOPER ST', '21 POTSDAM RD', '10 ROANOKE RD', '10 ROANOKE RD', '28 PHILPOTT GDNS', '66 EDGEWOOD AVE', '70 EDGEWOOD AVE', '2 COOPER ST', 'ROANOKE RD', '10 ROANOKE RD', 'OTTER CRES', '10 ROANOKE RD', '10 ROANOKE RD', '235 CARLAW AVE', '235 CARLAW AVE', '7 GLENBURN AVE', '90 EDGEWOOD AVE', '69 OTTER CRES', '1375 DUNDAS ST W', '27 BROCKVILLE ST', '122 EDGEWOOD AVE', '35 TOBERMORY DR', '69 OTTER CRES', '700 HUMBERWOOD BLVD', '30 CHARLES ST E', '425 KING ST W', '35 TOBERMORY DR', '30 CHARLES ST E', '103 WEST LODGE AVE', '8 SHOALHAVEN DR', '8 SHOALHAVEN DR', '73 AUGUSTA AVE', '30 CHARLES ST E', '33 FLAGMAN ST', '8 SHOALHAVEN DR', '8 SHOALHAVEN DR', '45 GRENOBLE DR', '30 CHARLES ST E', '30 CHARLES ST E', '88 COLGATE AVE', '1979 DUNDAS ST E', '30 CHARLES ST E', '88 COLGATE AVE', '5 VICORA LINKWAY', 'DRIFTWOOD AVE', '30 CHARLES ST E', '17 WHITEFRIARS DR', '41 LARK ST', 'DRIFTWOOD AVE', '19 WHITEFRIARS DR', '19 WHITEFRIARS DR', '335 DRIFTWOOD AVE', '85 PALM DR', '335 DRIFTWOOD AVE', '23 WHITEFRIARS DR', '1 CARR ST', '335 DRIFTWOOD AVE', '335 DRIFTWOOD AVE', '23 WHITEFRIARS DR', '335 DRIFTWOOD AVE', '25 BLYTH HILL RD', '325 GRANDRAVINE DR', '23 WHITEFRIARS DR', '1 OSBORNE AVE', '3 OSBORNE AVE', '90 RAINSFORD RD', '1 CARR ST', '335 DRIFTWOOD AVE', '43 BLYTH HILL RD', '27 WHITEFRIARS DR', '43 BLYTH HILL RD', '57 CARR ST', '347 DRIFTWOOD AVE', '57 CARR ST', '347 DRIFTWOOD AVE', '34 CELT AVE', '2 BLYTH DALE RD', '34 CELT AVE', '57 CARR ST', '22 WELSFORD GDNS', '65 OSBORNE AVE', '11 BATTENBERG AVE', '27 LONDON GREEN CRT', '22 WELSFORD GDNS', '22 WELSFORD GDNS', '27 LONDON GREEN CRT', '14 STRATHALLAN BLVD', '27 LONDON GREEN CRT', '14 WELSFORD GDNS', '11 LEONARD AVE', '23 LONDON GREEN CRT', '2 MEADOWGLEN PL', '55 CHISHOLM AVE', '40 FOUNTAINHEAD RD', '282 DAWLISH AVE', '19 LONDON GREEN CRT', '105 ROWENA DR', '97 PARKMOUNT RD', '40 FOUNTAINHEAD RD', '40 FOUNTAINHEAD RD', '19 LONDON GREEN CRT', '45 BENLAMOND AVE', '2 MEADOWGLEN PL', '40 FOUNTAINHEAD RD', '35 FOUNTAINHEAD RD']

# %%
#store clean addresses only
clean_locations = []
for location in locations:
    try:
        if(re.search(r'\d+\w+', location)):
            
            clean_locations.append(location)
    except:
        continue

# %%
print(len(clean_locations))
# Out:
# 1866991

# %%
clean_locations1 = clean_locations[:933495]

# %%
clean_locations2 = clean_locations[933495:]

# %%
clean_locations1 = list(dict.fromkeys(clean_locations1))

# %%
clean_locations2 = list(dict.fromkeys(clean_locations2))

# %%
clean_locations = clean_locations1 + clean_locations2
clean_locations = list(dict.fromkeys(clean_locations))

# %%
print(len(clean_locations))
# Out:
# 184775

# %%
df = pd.DataFrame({'location2':clean_locations})
df
# Out:
#                   location2
# 0             11 CENTRE AVE
# 1              2425 JANE ST
# 2            46 SPADINA AVE
# 3           39 LAKEVIEW AVE
# 4          21 CAMBRIDGE AVE
# 5          40 HIGH PARK AVE
# 6           30 KINGSWOOD RD
# 7          27 CAMBRIDGE AVE
# 8       145 STRATHMORE BLVD
# 9          49 CAMBRIDGE AVE
# 10             19 MACEY AVE
# 11           10 YUKON PLACE
# 12          60 KINGSWOOD RD
# 13      380 WELLINGTON ST W
# 14       87 STRATHMORE BLVD
# 15       14 LONDON GREEN CT
# 16          62 KINGSWOOD RD
# 17       85 STRATHMORE BLVD
# 18            178 DUPONT ST
# 19         70 HIGH PARK AVE
# 20          111 CHESTNUT ST
# 21            5351 YONGE ST
# 22      80 LYNN WILLIAMS ST
# 23         63 CAMBRIDGE AVE
# 24        14 LONDON GREE CT
# 25          98 KINGSWOOD RD
# 26        122 PATTERSON AVE
# 27         104 KINGSWOOD RD
# 28        149 CAMBRIDGE AVE
# 29             130 LAMB AVE
# ...                     ...
# 184745     495 MORTIMER AVE
# 184746      178 PARKSIDE DR
# 184747      712 COXWELL AVE
# 184748     733 WOODBINE AVE
# 184749     695 DANFORTH AVE
# 184750       127 ALMORE AVE
# 184751       28 O'CONNOR DR
# 184752     2453 DUNDAS ST W
# 184753     4962 DUNDAS ST W
# 184754   450 UNIVERSITY AVE
# 184755     175 CHISHOLM AVE
# 184756      409 COXWELL AVE
# 184757      400 COXWELL AVE
# 184758     933 GERRARD ST E
# 184759     13 KINGS LYNN RD
# 184760     922 GERRARD ST E
# 184761     939 GERRARD ST E
# 184762     11 KINGS LYNN RD
# 184763      13 KINGSMILL RD
# 184764       211 FRONT ST E
# 184765     419 MORTIMER AVE
# 184766       137 MUNRO BLVD
# 184767    295 ELLERSLIE AVE
# 184768      374 LUMSDEN AVE
# 184769   689 WINDERMERE AVE
# 184770     131 GOLFVIEW AVE
# 184771      80 GENTHORN AVE
# 184772      31 GENTHORN AVE
# 184773        19 KELVIN AVE
# 184774        757 KING ST W
#
# [184775 rows x 1 columns]

# %%
clean_df = pd.merge(tickets_2015_df,df,how="right",on='location2')
clean_df
# Out:
#         tag_number_masked  date_of_infraction  infraction_code  \
# 0                ***87325            20150101               15
# 1                ***87326            20150101               15
# 2                ***46332            20150102              210
# 3                ***15740            20150103              210
# 4                ***28049            20150104              210
# 5                ***76005            20150105              207
# 6                ***48604            20150106              210
# 7                ***48605            20150106              207
# 8                ***48635            20150107              207
# 9                ***48636            20150107              210
# 10               ***41660            20150107              207
# 11               ***48652            20150107              210
# 12               ***48653            20150107              207
# 13               ***45542            20150111              207
# 14               ***18893            20150112              210
# 15               ***18894            20150112              406
# 16               ***18895            20150112              207
# 17               ***18896            20150112              210
# 18               ***18897            20150112              210
# 19               ***00591            20150113                5
# 20               ***00593            20150113              210
# 21               ***00611            20150113              207
# 22               ***24612            20150115              210
# 23               ***24647            20150115              210
# 24               ***48412            20150115              210
# 25               ***04099            20150116              210
# 26               ***04100            20150116              406
# 27               ***04117            20150116              210
# 28               ***57763            20150118              207
# 29               ***79795            20150119              210
# ...                   ...                 ...              ...
# 1866961          ***16186            20151231              403
# 1866962          ***08284            20151231              403
# 1866963          ***42125            20151231               30
# 1866964          ***18675            20151231                5
# 1866965          ***69976            20151231              403
# 1866966          ***47041            20151231              403
# 1866967          ***78396            20151231              403
# 1866968          ***78398            20151231              403
# 1866969          ***31536            20151231                5
# 1866970          ***16200            20151231              403
# 1866971          ***16201            20151231                5
# 1866972          ***07064            20151231              403
# 1866973          ***47046            20151231                5
# 1866974          ***23540            20151231              403
# 1866975          ***23541            20151231              403
# 1866976          ***47047            20151231              406
# 1866977          ***47048            20151231                5
# 1866978          ***47049            20151231                5
# 1866979          ***47050            20151231                5
# 1866980          ***26255            20151231              403
# 1866981          ***31539            20151231              403
# 1866982          ***08292            20151231                6
# 1866983          ***42139            20151231               30
# 1866984          ***31550            20151231                5
# 1866985          ***47051            20151231               30
# 1866986          ***16224            20151231                5
# 1866987          ***47053            20151231                2
# 1866988          ***47054            20151231                2
# 1866989          ***06813            20151231              406
# 1866990          ***78777            20151231                5
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
# 0        PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 1        PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 2          PARK FAIL TO DISPLAY RECEIPT               30               814.0
# 3          PARK FAIL TO DISPLAY RECEIPT               30               816.0
# 4          PARK FAIL TO DISPLAY RECEIPT               30              2036.0
# 5         PARK FAIL TO DEP. FEE MACHINE               30              1117.0
# 6          PARK FAIL TO DISPLAY RECEIPT               30              1115.0
# 7         PARK FAIL TO DEP. FEE MACHINE               30              1117.0
# 8         PARK FAIL TO DEP. FEE MACHINE               30               928.0
# 9          PARK FAIL TO DISPLAY RECEIPT               30               930.0
# 10        PARK FAIL TO DEP. FEE MACHINE               30              1138.0
# 11         PARK FAIL TO DISPLAY RECEIPT               30              1240.0
# 12        PARK FAIL TO DEP. FEE MACHINE               30              1243.0
# 13        PARK FAIL TO DEP. FEE MACHINE               30              1441.0
# 14         PARK FAIL TO DISPLAY RECEIPT               30              1611.0
# 15        PARK-VEH. W/O VALID ONT PLATE               40              1614.0
# 16        PARK FAIL TO DEP. FEE MACHINE               30              1615.0
# 17         PARK FAIL TO DISPLAY RECEIPT               30              1617.0
# 18         PARK FAIL TO DISPLAY RECEIPT               30              1618.0
# 19       PARK-SIGNED HWY-PROHIBIT DY/TM               40               920.0
# 20         PARK FAIL TO DISPLAY RECEIPT               30               926.0
# 21        PARK FAIL TO DEP. FEE MACHINE               30              1122.0
# 22         PARK FAIL TO DISPLAY RECEIPT               30              1209.0
# 23         PARK FAIL TO DISPLAY RECEIPT               30              1551.0
# 24         PARK FAIL TO DISPLAY RECEIPT               30              1900.0
# 25         PARK FAIL TO DISPLAY RECEIPT               30              1807.0
# 26        PARK-VEH. W/O VALID ONT PLATE               40              1808.0
# 27         PARK FAIL TO DISPLAY RECEIPT               30              2003.0
# 28        PARK FAIL TO DEP. FEE MACHINE               30              2031.0
# 29         PARK FAIL TO DISPLAY RECEIPT               30               901.0
# ...                                 ...              ...                 ...
# 1866961   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1621.0
# 1866962   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1627.0
# 1866963  STOP-(ON/OVER) (SIDEWK/FTPATH)               60              1628.0
# 1866964  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1636.0
# 1866965   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1638.0
# 1866966   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1645.0
# 1866967   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1650.0
# 1866968   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1656.0
# 1866969  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1657.0
# 1866970   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1715.0
# 1866971  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1716.0
# 1866972   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1717.0
# 1866973  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1717.0
# 1866974   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1718.0
# 1866975   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1718.0
# 1866976   PARK-VEH. W/O VALID ONT PLATE               40              1718.0
# 1866977  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1718.0
# 1866978  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1719.0
# 1866979  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1721.0
# 1866980   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1727.0
# 1866981   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1727.0
# 1866982  PARK-SIGNED HWY-EXC PERMT TIME               40              1729.0
# 1866983  STOP-(ON/OVER) (SIDEWK/FTPATH)               60              1817.0
# 1866984  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1858.0
# 1866985  STOP-(ON/OVER) (SIDEWK/FTPATH)               60              1917.0
# 1866986  PARK-SIGNED HWY-PROHIBIT DY/TM               40              1924.0
# 1866987     PARK - LONGER THAN 3 HOURS                15              2009.0
# 1866988     PARK - LONGER THAN 3 HOURS                15              2011.0
# 1866989   PARK-VEH. W/O VALID ONT PLATE               40              2058.0
# 1866990  PARK-SIGNED HWY-PROHIBIT DY/TM               40              2230.0
#
#         location1           location2 location3 location4 province
# 0             OPP       11 CENTRE AVE       NaN       NaN       ON
# 1             OPP       11 CENTRE AVE       NaN       NaN       ON
# 2              NR       11 CENTRE AVE       NaN       NaN       QC
# 3             OPP       11 CENTRE AVE       NaN       NaN       ON
# 4              NR       11 CENTRE AVE       NaN       NaN       ON
# 5             OPP       11 CENTRE AVE       NaN       NaN       ON
# 6              NR       11 CENTRE AVE       NaN       NaN       QC
# 7              NR       11 CENTRE AVE       NaN       NaN       ON
# 8              NR       11 CENTRE AVE       NaN       NaN       ON
# 9              NR       11 CENTRE AVE       NaN       NaN       AB
# 10             NR       11 CENTRE AVE       NaN       NaN       ON
# 11             NR       11 CENTRE AVE       NaN       NaN       AB
# 12            OPP       11 CENTRE AVE       NaN       NaN       ON
# 13             NR       11 CENTRE AVE       NaN       NaN       ON
# 14            OPP       11 CENTRE AVE       NaN       NaN       ON
# 15             NR       11 CENTRE AVE       NaN       NaN       ON
# 16             NR       11 CENTRE AVE       NaN       NaN       ON
# 17             NR       11 CENTRE AVE       NaN       NaN       AB
# 18             NR       11 CENTRE AVE       NaN       NaN       ON
# 19             NR       11 CENTRE AVE       NaN       NaN       ON
# 20             NR       11 CENTRE AVE       NaN       NaN       ON
# 21             NR       11 CENTRE AVE       NaN       NaN       ON
# 22             NR       11 CENTRE AVE       NaN       NaN       AB
# 23             NR       11 CENTRE AVE       NaN       NaN       AB
# 24            OPP       11 CENTRE AVE       NaN       NaN       QC
# 25             NR       11 CENTRE AVE       NaN       NaN       ON
# 26             NR       11 CENTRE AVE       NaN       NaN       ON
# 27            OPP       11 CENTRE AVE       NaN       NaN       NY
# 28             NR       11 CENTRE AVE       NaN       NaN       ON
# 29             NR       11 CENTRE AVE       NaN       NaN       ON
# ...           ...                 ...       ...       ...      ...
# 1866961        NR    733 WOODBINE AVE       NaN       NaN       ON
# 1866962        NR    695 DANFORTH AVE       NaN       NaN       ON
# 1866963        NR      127 ALMORE AVE       NaN       NaN       ON
# 1866964        NR      28 O'CONNOR DR       NaN       NaN       ON
# 1866965        NR    2453 DUNDAS ST W       NaN       NaN       ON
# 1866966        NR    4962 DUNDAS ST W       NaN       NaN       QC
# 1866967        NR  450 UNIVERSITY AVE       NaN       NaN       ON
# 1866968        NR  450 UNIVERSITY AVE       NaN       NaN       ON
# 1866969       OPP    175 CHISHOLM AVE       NaN       NaN       ON
# 1866970        NR     409 COXWELL AVE       NaN       NaN       ON
# 1866971        NR     400 COXWELL AVE       NaN       NaN       ON
# 1866972        NR    933 GERRARD ST E       NaN       NaN       QC
# 1866973        NR    13 KINGS LYNN RD       NaN       NaN       ON
# 1866974        NR    922 GERRARD ST E       NaN       NaN       ON
# 1866975        NR    939 GERRARD ST E       NaN       NaN       ON
# 1866976        NR    11 KINGS LYNN RD       NaN       NaN       ON
# 1866977        NR    11 KINGS LYNN RD       NaN       NaN       ON
# 1866978        NR    11 KINGS LYNN RD       NaN       NaN       ON
# 1866979        NR     13 KINGSMILL RD       NaN       NaN       ON
# 1866980        NR      211 FRONT ST E       NaN       NaN       ON
# 1866981        NR    419 MORTIMER AVE       NaN       NaN       ON
# 1866982        NR      137 MUNRO BLVD       NaN       NaN       ON
# 1866983        NR   295 ELLERSLIE AVE       NaN       NaN       ON
# 1866984        NR     374 LUMSDEN AVE       NaN       NaN       ON
# 1866985       OPP  689 WINDERMERE AVE       NaN       NaN       ON
# 1866986        NR    131 GOLFVIEW AVE       NaN       NaN       ON
# 1866987        NR     80 GENTHORN AVE       NaN       NaN       ON
# 1866988        NR     31 GENTHORN AVE       NaN       NaN       ON
# 1866989        NR       19 KELVIN AVE       NaN       NaN       ON
# 1866990       NaN       757 KING ST W       NaN       NaN       NJ
#
# [1866991 rows x 11 columns]

# %%
index = np.arange(0,len(clean_df))
clean_df["id"] = index
clean_df.set_index("id",inplace=True)
clean_df=clean_df[["date_of_infraction","infraction_code","infraction_description","set_fine_amount","time_of_infraction","location2"]]
clean_df
# Out:
#          date_of_infraction  infraction_code          infraction_description  \
# id
# 0                  20150101               15  PARK-WITHIN 3M OF FIRE HYDRANT
# 1                  20150101               15  PARK-WITHIN 3M OF FIRE HYDRANT
# 2                  20150102              210    PARK FAIL TO DISPLAY RECEIPT
# 3                  20150103              210    PARK FAIL TO DISPLAY RECEIPT
# 4                  20150104              210    PARK FAIL TO DISPLAY RECEIPT
# 5                  20150105              207   PARK FAIL TO DEP. FEE MACHINE
# 6                  20150106              210    PARK FAIL TO DISPLAY RECEIPT
# 7                  20150106              207   PARK FAIL TO DEP. FEE MACHINE
# 8                  20150107              207   PARK FAIL TO DEP. FEE MACHINE
# 9                  20150107              210    PARK FAIL TO DISPLAY RECEIPT
# 10                 20150107              207   PARK FAIL TO DEP. FEE MACHINE
# 11                 20150107              210    PARK FAIL TO DISPLAY RECEIPT
# 12                 20150107              207   PARK FAIL TO DEP. FEE MACHINE
# 13                 20150111              207   PARK FAIL TO DEP. FEE MACHINE
# 14                 20150112              210    PARK FAIL TO DISPLAY RECEIPT
# 15                 20150112              406   PARK-VEH. W/O VALID ONT PLATE
# 16                 20150112              207   PARK FAIL TO DEP. FEE MACHINE
# 17                 20150112              210    PARK FAIL TO DISPLAY RECEIPT
# 18                 20150112              210    PARK FAIL TO DISPLAY RECEIPT
# 19                 20150113                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 20                 20150113              210    PARK FAIL TO DISPLAY RECEIPT
# 21                 20150113              207   PARK FAIL TO DEP. FEE MACHINE
# 22                 20150115              210    PARK FAIL TO DISPLAY RECEIPT
# 23                 20150115              210    PARK FAIL TO DISPLAY RECEIPT
# 24                 20150115              210    PARK FAIL TO DISPLAY RECEIPT
# 25                 20150116              210    PARK FAIL TO DISPLAY RECEIPT
# 26                 20150116              406   PARK-VEH. W/O VALID ONT PLATE
# 27                 20150116              210    PARK FAIL TO DISPLAY RECEIPT
# 28                 20150118              207   PARK FAIL TO DEP. FEE MACHINE
# 29                 20150119              210    PARK FAIL TO DISPLAY RECEIPT
# ...                     ...              ...                             ...
# 1866961            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866962            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866963            20151231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1866964            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866965            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866966            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866967            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866968            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866969            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866970            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866971            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866972            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866973            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866974            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866975            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866976            20151231              406   PARK-VEH. W/O VALID ONT PLATE
# 1866977            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866978            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866979            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866980            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866981            20151231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1866982            20151231                6  PARK-SIGNED HWY-EXC PERMT TIME
# 1866983            20151231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1866984            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866985            20151231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1866986            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1866987            20151231                2     PARK - LONGER THAN 3 HOURS
# 1866988            20151231                2     PARK - LONGER THAN 3 HOURS
# 1866989            20151231              406   PARK-VEH. W/O VALID ONT PLATE
# 1866990            20151231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
#
#          set_fine_amount  time_of_infraction           location2
# id
# 0                    100                 1.0       11 CENTRE AVE
# 1                    100                 1.0       11 CENTRE AVE
# 2                     30               814.0       11 CENTRE AVE
# 3                     30               816.0       11 CENTRE AVE
# 4                     30              2036.0       11 CENTRE AVE
# 5                     30              1117.0       11 CENTRE AVE
# 6                     30              1115.0       11 CENTRE AVE
# 7                     30              1117.0       11 CENTRE AVE
# 8                     30               928.0       11 CENTRE AVE
# 9                     30               930.0       11 CENTRE AVE
# 10                    30              1138.0       11 CENTRE AVE
# 11                    30              1240.0       11 CENTRE AVE
# 12                    30              1243.0       11 CENTRE AVE
# 13                    30              1441.0       11 CENTRE AVE
# 14                    30              1611.0       11 CENTRE AVE
# 15                    40              1614.0       11 CENTRE AVE
# 16                    30              1615.0       11 CENTRE AVE
# 17                    30              1617.0       11 CENTRE AVE
# 18                    30              1618.0       11 CENTRE AVE
# 19                    40               920.0       11 CENTRE AVE
# 20                    30               926.0       11 CENTRE AVE
# 21                    30              1122.0       11 CENTRE AVE
# 22                    30              1209.0       11 CENTRE AVE
# 23                    30              1551.0       11 CENTRE AVE
# 24                    30              1900.0       11 CENTRE AVE
# 25                    30              1807.0       11 CENTRE AVE
# 26                    40              1808.0       11 CENTRE AVE
# 27                    30              2003.0       11 CENTRE AVE
# 28                    30              2031.0       11 CENTRE AVE
# 29                    30               901.0       11 CENTRE AVE
# ...                  ...                 ...                 ...
# 1866961              150              1621.0    733 WOODBINE AVE
# 1866962              150              1627.0    695 DANFORTH AVE
# 1866963               60              1628.0      127 ALMORE AVE
# 1866964               40              1636.0      28 O'CONNOR DR
# 1866965              150              1638.0    2453 DUNDAS ST W
# 1866966              150              1645.0    4962 DUNDAS ST W
# 1866967              150              1650.0  450 UNIVERSITY AVE
# 1866968              150              1656.0  450 UNIVERSITY AVE
# 1866969               40              1657.0    175 CHISHOLM AVE
# 1866970              150              1715.0     409 COXWELL AVE
# 1866971               40              1716.0     400 COXWELL AVE
# 1866972              150              1717.0    933 GERRARD ST E
# 1866973               40              1717.0    13 KINGS LYNN RD
# 1866974              150              1718.0    922 GERRARD ST E
# 1866975              150              1718.0    939 GERRARD ST E
# 1866976               40              1718.0    11 KINGS LYNN RD
# 1866977               40              1718.0    11 KINGS LYNN RD
# 1866978               40              1719.0    11 KINGS LYNN RD
# 1866979               40              1721.0     13 KINGSMILL RD
# 1866980              150              1727.0      211 FRONT ST E
# 1866981              150              1727.0    419 MORTIMER AVE
# 1866982               40              1729.0      137 MUNRO BLVD
# 1866983               60              1817.0   295 ELLERSLIE AVE
# 1866984               40              1858.0     374 LUMSDEN AVE
# 1866985               60              1917.0  689 WINDERMERE AVE
# 1866986               40              1924.0    131 GOLFVIEW AVE
# 1866987               15              2009.0     80 GENTHORN AVE
# 1866988               15              2011.0     31 GENTHORN AVE
# 1866989               40              2058.0       19 KELVIN AVE
# 1866990               40              2230.0       757 KING ST W
#
# [1866991 rows x 6 columns]

# %%
#Create SQL connection
rds_connection_string = "root:root123@127.0.0.1:3306/parking_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
#Check for table
engine.table_names()

# %%
#Export to SQL. If table already exists, data will be appended
merged_df.to_sql(name='parking_tickets', con=engine, if_exists='append', index=True)
