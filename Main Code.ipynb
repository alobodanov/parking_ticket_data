# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import json
import numpy as np
import re

# %%
csv_tickets_1 = "parkingTicketData/Resources/parking_tickets_2018/Parking_Tags_Data_2018_1.csv"
ticket_df_1 = pd.read_csv(csv_tickets_1)
#ticket_df_1["date_of_infraction"] = ticket_df_1["date_of_infraction"].astype(int)
ticket_df_1.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***92517            20180101               16
# 1          ***71708            20180101               29
# 2          ***92311            20180101               29
# 3          ***92312            20180101               29
# 4          ***71709            20180101               29
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0   PARK-WITHIN 9M INTERSECT ROAD               50                 0.0
# 1  PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 2  PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 3  PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 4  PARK PROHIBITED TIME NO PERMIT               30                 3.0
#
#   location1          location2 location3      location4 province
# 0       S/S          PRYOR AVE       E/O  CLOVERDALE RD       ON
# 1        NR  266 DOVERCOURT RD       NaN            NaN       ON
# 2        NR    15 FAIRBANK AVE       NaN            NaN       ON
# 3        NR    15 FAIRBANK AVE       NaN            NaN       ON
# 4        NR  266 DOVERCOURT RD       NaN            NaN       ON

# %%
csv_tickets_2 = "parkingTicketData/Resources/parking_tickets_2018/Parking_Tags_Data_2018_2.csv"
ticket_df_2 = pd.read_csv(csv_tickets_2)
#ticket_df_1["date_of_infraction"] = ticket_df_1["date_of_infraction"].astype(int)
ticket_df_2.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***73270            20180517              207
# 1          ***70858            20180517              307
# 2          ***68492            20180517              415
# 3          ***05781            20180517              207
# 4          ***06686            20180517              207
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0  PARK MACHINE-REQD FEE NOT PAID               30              1237.0
# 1   PARK VEHICLE OUTSIDE OF SPACE               30              1238.0
# 2  PARK COMMERC LOAD ZONE NOT LDG               40              1238.0
# 3  PARK MACHINE-REQD FEE NOT PAID               30              1238.0
# 4  PARK MACHINE-REQD FEE NOT PAID               30              1238.0
#
#   location1         location2 location3 location4 province
# 0        NR     11 CENTRE AVE       NaN       NaN       ON
# 1       NaN    1155 KING ST W       NaN       NaN       ON
# 2       OPP      21 SULTAN ST       NaN       NaN       ON
# 3        NR    886 QUEEN ST W       NaN       NaN       ON
# 4       OPP  90 RICHMOND ST E       NaN       NaN       ON

# %%
csv_tickets_3 = "parkingTicketData/Resources/parking_tickets_2018/Parking_Tags_Data_2018_3.csv"
ticket_df_3 = pd.read_csv(csv_tickets_3)
#ticket_df_1["date_of_infraction"] = ticket_df_1["date_of_infraction"].astype(int)
ticket_df_3.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***91886            20180929                2
# 1          ***18291            20180929              207
# 2          ***26058            20180929                5
# 3          ***16679            20180929               29
# 4          ***18292            20180929              406
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0      PARK - LONGER THAN 3 HOURS               15              2233.0
# 1  PARK MACHINE-REQD FEE NOT PAID               30              2233.0
# 2  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2233.0
# 3  PARK PROHIBITED TIME NO PERMIT               30              2234.0
# 4   PARK-VEH. W/O VALID ONT PLATE               40              2234.0
#
#   location1       location2 location3    location4 province
# 0       W/S       RUMNEY RD       N/O  TRENTON AVE       ON
# 1        NR  390 QUEEN ST W       NaN          NaN       ON
# 2        NR    10 EDWARD ST       NaN          NaN       ON
# 3        NR  55 MAITLAND ST       NaN          NaN       ON
# 4        NR  390 QUEEN ST W       NaN          NaN       ON

# %%
tickets_2015_df=pd.concat([ticket_df_1,ticket_df_2,ticket_df_3])
locations = list(tickets_2015_df["location2"])

# %%
#store clean addresses only
clean_locations = []
for location in locations:
    try:
        if(re.search(r'\d+\w+', location)):
            
            clean_locations.append(location)
    except:
        continue

# %%
print(len(clean_locations))
# Out:
# 1742565

# %%
clean_locations1 = clean_locations[:933495]

# %%
clean_locations2 = clean_locations[933495:]

# %%
clean_locations1 = list(dict.fromkeys(clean_locations1))

# %%
clean_locations2 = list(dict.fromkeys(clean_locations2))

# %%
clean_locations = clean_locations1 + clean_locations2
clean_locations = list(dict.fromkeys(clean_locations))

# %%
print(len(clean_locations))
# Out:
# 179468

# %%
df = pd.DataFrame({'location2':clean_locations})
df
# Out:
#                    location2
# 0          266 DOVERCOURT RD
# 1            15 FAIRBANK AVE
# 2             735 COLLEGE ST
# 3          262 DOVERCOURT RD
# 4          234 DOVERCOURT RD
# 5          220 DOVERCOURT RD
# 6         73 CHAMBERLAIN AVE
# 7          210 DOVERCOURT RD
# 8          215 DOVERCOURT RD
# 9         65 CHAMBERLAIN AVE
# 10         202 DOVERCOURT RD
# 11        45 CHAMBERLAIN AVE
# 12        38 CHAMBERLAIN AVE
# 13              281 OSLER ST
# 14             68 SNIDER AVE
# 15             32 DE JONG ST
# 16             74 SNIDER AVE
# 17            410 COLLEGE ST
# 18            200 SCHELL AVE
# 19              54 ZEZEL WAY
# 20             146 BOWIE AVE
# 21             120 BOWIE AVE
# 22             104 BOWIE AVE
# 23             103 BOWIE AVE
# 24        639 ST CLARENS AVE
# 25           1294 QUEEN ST W
# 26        25 TOWN CENTRE CRT
# 27              52 BOWIE AVE
# 28        633 ST CLARENS AVE
# 29        631 ST CLARENS AVE
# ...                      ...
# 179438    381 UNIVERSITY AVE
# 179439     685 DOVERWOOD CRT
# 179440        63 KINGSTON RD
# 179441      30 NINETEENTH ST
# 179442       616 COXWELL AVE
# 179443     911 LANSDOWNE AVE
# 179444        5400 WESTON RD
# 179445   174 THIRTY THIRD ST
# 179446       767 KINGSTON RD
# 179447           85 KEELE ST
# 179448  40 WELLESBOURNE CRES
# 179449  840 QUEEN'S PLATE DR
# 179450   2160 ST CLAIR AVE W
# 179451   2287 EGLINTON AVE W
# 179452       177 BINGHAM AVE
# 179453        99 SCARLETT RD
# 179454      120 GERRARD ST E
# 179455    54 A BELLWOODS AVE
# 179456       14 MOSSFORD CRT
# 179457     298 HILLMOUNT AVE
# 179458          34 GOUGH AVE
# 179459         87 BASTION ST
# 179460        29 WINKLER TER
# 179461     3816 DANFORTH AVE
# 179462        3191 WESTON RD
# 179463            26 YORK ST
# 179464       126 SENTINEL RD
# 179465        71 SENTINEL RD
# 179466       282 GILLARD AVE
# 179467  40 SPRING GARDEN AVE
#
# [179468 rows x 1 columns]

# %%
clean_df = pd.merge(tickets_2015_df,df,how="right",on='location2')
clean_df
# Out:
#         tag_number_masked  date_of_infraction  infraction_code  \
# 0                ***71708            20180101               29
# 1                ***71709            20180101               29
# 2                ***71711            20180101               29
# 3                ***22279            20180122               29
# 4                ***75572            20180514               29
# 5                ***25811            20180529               29
# 6                ***81949            20180623               29
# 7                ***29074            20180629               29
# 8                ***21816            20180820               29
# 9                ***94401            20180905               29
# 10               ***21434            20180930               29
# 11               ***76719            20181017              406
# 12               ***76728            20181017                6
# 13               ***29437            20181109                6
# 14               ***04995            20181109              406
# 15               ***30797            20181127              406
# 16               ***53592            20181205              406
# 17               ***92311            20180101               29
# 18               ***92312            20180101               29
# 19               ***92313            20180101               29
# 20               ***63204            20180306               29
# 21               ***94129            20180310               29
# 22               ***11271            20180330               29
# 23               ***25761            20180410               29
# 24               ***87572            20180413               29
# 25               ***87639            20180414               29
# 26               ***76952            20180520               29
# 27               ***21825            20180714               29
# 28               ***73023            20180101                3
# 29               ***73024            20180101                3
# ...                   ...                 ...              ...
# 1742535          ***33447            20181231                3
# 1742536          ***22191            20181231                5
# 1742537          ***35668            20181231              403
# 1742538          ***35669            20181231              403
# 1742539          ***25360            20181231              403
# 1742540          ***25361            20181231              403
# 1742541          ***58872            20181231                5
# 1742542          ***58873            20181231              406
# 1742543          ***53155            20181231                3
# 1742544          ***53156            20181231              355
# 1742545          ***53157            20181231              355
# 1742546          ***24526            20181231              403
# 1742547          ***36151            20181231              403
# 1742548          ***35673            20181231                6
# 1742549          ***24533            20181231                5
# 1742550          ***35206            20181231              207
# 1742551          ***25484            20181231               29
# 1742552          ***53158            20181231               49
# 1742553          ***36159            20181231               49
# 1742554          ***37263            20181231               29
# 1742555          ***25492            20181231                3
# 1742556          ***59290            20181231               49
# 1742557          ***57653            20181231                5
# 1742558          ***33484            20181231               30
# 1742559          ***63663            20181231                5
# 1742560          ***33485            20181231               30
# 1742561          ***33486            20181231               30
# 1742562          ***33487            20181231               30
# 1742563          ***00696            20181231                5
# 1742564          ***28387            20181231                9
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
# 0        PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 1        PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 2        PARK PROHIBITED TIME NO PERMIT               30                 5.0
# 3        PARK PROHIBITED TIME NO PERMIT               30                48.0
# 4        PARK PROHIBITED TIME NO PERMIT               30                31.0
# 5        PARK PROHIBITED TIME NO PERMIT               30                28.0
# 6        PARK PROHIBITED TIME NO PERMIT               30                40.0
# 7        PARK PROHIBITED TIME NO PERMIT               30               225.0
# 8        PARK PROHIBITED TIME NO PERMIT               30               123.0
# 9        PARK PROHIBITED TIME NO PERMIT               30                25.0
# 10       PARK PROHIBITED TIME NO PERMIT               30               119.0
# 11        PARK-VEH. W/O VALID ONT PLATE               40              1158.0
# 12       PARK-SIGNED HWY-EXC PERMT TIME               40              1305.0
# 13       PARK-SIGNED HWY-EXC PERMT TIME               40              1408.0
# 14        PARK-VEH. W/O VALID ONT PLATE               40              1631.0
# 15        PARK-VEH. W/O VALID ONT PLATE               40              1917.0
# 16        PARK-VEH. W/O VALID ONT PLATE               40              1854.0
# 17       PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 18       PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 19       PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 20       PARK PROHIBITED TIME NO PERMIT               30                 4.0
# 21       PARK PROHIBITED TIME NO PERMIT               30                 6.0
# 22       PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 23       PARK PROHIBITED TIME NO PERMIT               30                 5.0
# 24       PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 25       PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 26       PARK PROHIBITED TIME NO PERMIT               30                 7.0
# 27       PARK PROHIBITED TIME NO PERMIT               30                 4.0
# 28             PARK ON PRIVATE PROPERTY               30                 3.0
# 29             PARK ON PRIVATE PROPERTY               30                 3.0
# ...                                 ...              ...                 ...
# 1742535        PARK ON PRIVATE PROPERTY               30              1632.0
# 1742536  PARK-SIGNED HWY-PROHIBIT DY/TM               50              1638.0
# 1742537   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1644.0
# 1742538   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1646.0
# 1742539   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1706.0
# 1742540   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1707.0
# 1742541  PARK-SIGNED HWY-PROHIBIT DY/TM               50              1707.0
# 1742542   PARK-VEH. W/O VALID ONT PLATE               40              1708.0
# 1742543        PARK ON PRIVATE PROPERTY               30              1709.0
# 1742544    PARK IN ACCESSIBLE NO PERMIT              450              1714.0
# 1742545    PARK IN ACCESSIBLE NO PERMIT              450              1714.0
# 1742546   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1719.0
# 1742547   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1728.0
# 1742548  PARK-SIGNED HWY-EXC PERMT TIME               40              1733.0
# 1742549  PARK-SIGNED HWY-PROHIBIT DY/TM               50              1742.0
# 1742550  PARK MACHINE-REQD FEE NOT PAID               30              1754.0
# 1742551  PARK PROHIBITED TIME NO PERMIT               30              1820.0
# 1742552  FAIL TO PARK/STOP PARALL. RGHT               30              1859.0
# 1742553  FAIL TO PARK/STOP PARALL. RGHT               30              1901.0
# 1742554  PARK PROHIBITED TIME NO PERMIT               30              1911.0
# 1742555        PARK ON PRIVATE PROPERTY               30              1923.0
# 1742556  FAIL TO PARK/STOP PARALL. RGHT               30              2028.0
# 1742557  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2053.0
# 1742558  STOP-(ON/OVER) (SIDEWK/FTPATH)              150              2128.0
# 1742559  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2128.0
# 1742560  STOP-(ON/OVER) (SIDEWK/FTPATH)              150              2153.0
# 1742561  STOP-(ON/OVER) (SIDEWK/FTPATH)              150              2156.0
# 1742562  STOP-(ON/OVER) (SIDEWK/FTPATH)              150              2157.0
# 1742563  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2357.0
# 1742564  STOP-SIGNED HWY-PROHIBIT TM/DY               60              2359.0
#
#         location1             location2 location3 location4 province
# 0              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 1              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 2              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 3              NR     266 DOVERCOURT RD       NaN       NaN       NS
# 4              NR     266 DOVERCOURT RD       NaN       NaN       NS
# 5              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 6              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 7              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 8              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 9              NR     266 DOVERCOURT RD       NaN       NaN       ON
# 10             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 11             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 12             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 13             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 14             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 15             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 16             NR     266 DOVERCOURT RD       NaN       NaN       ON
# 17             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 18             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 19             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 20             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 21             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 22             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 23             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 24             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 25             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 26             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 27             NR       15 FAIRBANK AVE       NaN       NaN       ON
# 28             AT        735 COLLEGE ST       NaN       NaN       ON
# 29             AT        735 COLLEGE ST       NaN       NaN       ON
# ...           ...                   ...       ...       ...      ...
# 1742535        AT        5400 WESTON RD       NaN       NaN       ON
# 1742536        NR   174 THIRTY THIRD ST       NaN       NaN       ON
# 1742537        NR       767 KINGSTON RD       NaN       NaN       ON
# 1742538        NR       767 KINGSTON RD       NaN       NaN       ON
# 1742539        NR           85 KEELE ST       NaN       NaN       ON
# 1742540        NR           85 KEELE ST       NaN       NaN       ON
# 1742541        NR  40 WELLESBOURNE CRES       NaN       NaN       ON
# 1742542        NR  40 WELLESBOURNE CRES       NaN       NaN       ON
# 1742543        AT  840 QUEEN'S PLATE DR       NaN       NaN       ON
# 1742544        AT  840 QUEEN'S PLATE DR       NaN       NaN       ON
# 1742545        AT  840 QUEEN'S PLATE DR       NaN       NaN       ON
# 1742546        NR   2160 ST CLAIR AVE W       NaN       NaN       ON
# 1742547        NR   2287 EGLINTON AVE W       NaN       NaN       ON
# 1742548        NR       177 BINGHAM AVE       NaN       NaN       WA
# 1742549        NR        99 SCARLETT RD       NaN       NaN       ON
# 1742550        NR      120 GERRARD ST E       NaN       NaN       ON
# 1742551        NR    54 A BELLWOODS AVE       NaN       NaN       ON
# 1742552        NR       14 MOSSFORD CRT       NaN       NaN       ON
# 1742553        NR     298 HILLMOUNT AVE       NaN       NaN       QC
# 1742554        NR          34 GOUGH AVE       NaN       NaN       ON
# 1742555        AT         87 BASTION ST       NaN       NaN       ON
# 1742556        NR        29 WINKLER TER       NaN       NaN       ON
# 1742557        NR     3816 DANFORTH AVE       NaN       NaN       ON
# 1742558        NR        3191 WESTON RD       NaN       NaN       ON
# 1742559        NR            26 YORK ST       NaN       NaN       ON
# 1742560        NR       126 SENTINEL RD       NaN       NaN       ON
# 1742561        NR        71 SENTINEL RD       NaN       NaN       ON
# 1742562        NR        71 SENTINEL RD       NaN       NaN       ON
# 1742563        NR       282 GILLARD AVE       NaN       NaN       ON
# 1742564        NR  40 SPRING GARDEN AVE       NaN       NaN       ON
#
# [1742565 rows x 11 columns]

# %%
index = np.arange(0,len(clean_df))
clean_df["id"] = index
clean_df.set_index("id",inplace=True)
clean_df=clean_df[["date_of_infraction","infraction_code","infraction_description","set_fine_amount","time_of_infraction","location2"]]
clean_df
# Out:
#          date_of_infraction  infraction_code          infraction_description  \
# id
# 0                  20180101               29  PARK PROHIBITED TIME NO PERMIT
# 1                  20180101               29  PARK PROHIBITED TIME NO PERMIT
# 2                  20180101               29  PARK PROHIBITED TIME NO PERMIT
# 3                  20180122               29  PARK PROHIBITED TIME NO PERMIT
# 4                  20180514               29  PARK PROHIBITED TIME NO PERMIT
# 5                  20180529               29  PARK PROHIBITED TIME NO PERMIT
# 6                  20180623               29  PARK PROHIBITED TIME NO PERMIT
# 7                  20180629               29  PARK PROHIBITED TIME NO PERMIT
# 8                  20180820               29  PARK PROHIBITED TIME NO PERMIT
# 9                  20180905               29  PARK PROHIBITED TIME NO PERMIT
# 10                 20180930               29  PARK PROHIBITED TIME NO PERMIT
# 11                 20181017              406   PARK-VEH. W/O VALID ONT PLATE
# 12                 20181017                6  PARK-SIGNED HWY-EXC PERMT TIME
# 13                 20181109                6  PARK-SIGNED HWY-EXC PERMT TIME
# 14                 20181109              406   PARK-VEH. W/O VALID ONT PLATE
# 15                 20181127              406   PARK-VEH. W/O VALID ONT PLATE
# 16                 20181205              406   PARK-VEH. W/O VALID ONT PLATE
# 17                 20180101               29  PARK PROHIBITED TIME NO PERMIT
# 18                 20180101               29  PARK PROHIBITED TIME NO PERMIT
# 19                 20180101               29  PARK PROHIBITED TIME NO PERMIT
# 20                 20180306               29  PARK PROHIBITED TIME NO PERMIT
# 21                 20180310               29  PARK PROHIBITED TIME NO PERMIT
# 22                 20180330               29  PARK PROHIBITED TIME NO PERMIT
# 23                 20180410               29  PARK PROHIBITED TIME NO PERMIT
# 24                 20180413               29  PARK PROHIBITED TIME NO PERMIT
# 25                 20180414               29  PARK PROHIBITED TIME NO PERMIT
# 26                 20180520               29  PARK PROHIBITED TIME NO PERMIT
# 27                 20180714               29  PARK PROHIBITED TIME NO PERMIT
# 28                 20180101                3        PARK ON PRIVATE PROPERTY
# 29                 20180101                3        PARK ON PRIVATE PROPERTY
# ...                     ...              ...                             ...
# 1742535            20181231                3        PARK ON PRIVATE PROPERTY
# 1742536            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742537            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742538            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742539            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742540            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742541            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742542            20181231              406   PARK-VEH. W/O VALID ONT PLATE
# 1742543            20181231                3        PARK ON PRIVATE PROPERTY
# 1742544            20181231              355    PARK IN ACCESSIBLE NO PERMIT
# 1742545            20181231              355    PARK IN ACCESSIBLE NO PERMIT
# 1742546            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742547            20181231              403   STOP-SIGNED HIGHWAY-RUSH HOUR
# 1742548            20181231                6  PARK-SIGNED HWY-EXC PERMT TIME
# 1742549            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742550            20181231              207  PARK MACHINE-REQD FEE NOT PAID
# 1742551            20181231               29  PARK PROHIBITED TIME NO PERMIT
# 1742552            20181231               49  FAIL TO PARK/STOP PARALL. RGHT
# 1742553            20181231               49  FAIL TO PARK/STOP PARALL. RGHT
# 1742554            20181231               29  PARK PROHIBITED TIME NO PERMIT
# 1742555            20181231                3        PARK ON PRIVATE PROPERTY
# 1742556            20181231               49  FAIL TO PARK/STOP PARALL. RGHT
# 1742557            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742558            20181231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1742559            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742560            20181231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1742561            20181231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1742562            20181231               30  STOP-(ON/OVER) (SIDEWK/FTPATH)
# 1742563            20181231                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 1742564            20181231                9  STOP-SIGNED HWY-PROHIBIT TM/DY
#
#          set_fine_amount  time_of_infraction             location2
# id
# 0                     30                 2.0     266 DOVERCOURT RD
# 1                     30                 3.0     266 DOVERCOURT RD
# 2                     30                 5.0     266 DOVERCOURT RD
# 3                     30                48.0     266 DOVERCOURT RD
# 4                     30                31.0     266 DOVERCOURT RD
# 5                     30                28.0     266 DOVERCOURT RD
# 6                     30                40.0     266 DOVERCOURT RD
# 7                     30               225.0     266 DOVERCOURT RD
# 8                     30               123.0     266 DOVERCOURT RD
# 9                     30                25.0     266 DOVERCOURT RD
# 10                    30               119.0     266 DOVERCOURT RD
# 11                    40              1158.0     266 DOVERCOURT RD
# 12                    40              1305.0     266 DOVERCOURT RD
# 13                    40              1408.0     266 DOVERCOURT RD
# 14                    40              1631.0     266 DOVERCOURT RD
# 15                    40              1917.0     266 DOVERCOURT RD
# 16                    40              1854.0     266 DOVERCOURT RD
# 17                    30                 2.0       15 FAIRBANK AVE
# 18                    30                 2.0       15 FAIRBANK AVE
# 19                    30                 3.0       15 FAIRBANK AVE
# 20                    30                 4.0       15 FAIRBANK AVE
# 21                    30                 6.0       15 FAIRBANK AVE
# 22                    30                 3.0       15 FAIRBANK AVE
# 23                    30                 5.0       15 FAIRBANK AVE
# 24                    30                 3.0       15 FAIRBANK AVE
# 25                    30                 3.0       15 FAIRBANK AVE
# 26                    30                 7.0       15 FAIRBANK AVE
# 27                    30                 4.0       15 FAIRBANK AVE
# 28                    30                 3.0        735 COLLEGE ST
# 29                    30                 3.0        735 COLLEGE ST
# ...                  ...                 ...                   ...
# 1742535               30              1632.0        5400 WESTON RD
# 1742536               50              1638.0   174 THIRTY THIRD ST
# 1742537              150              1644.0       767 KINGSTON RD
# 1742538              150              1646.0       767 KINGSTON RD
# 1742539              150              1706.0           85 KEELE ST
# 1742540              150              1707.0           85 KEELE ST
# 1742541               50              1707.0  40 WELLESBOURNE CRES
# 1742542               40              1708.0  40 WELLESBOURNE CRES
# 1742543               30              1709.0  840 QUEEN'S PLATE DR
# 1742544              450              1714.0  840 QUEEN'S PLATE DR
# 1742545              450              1714.0  840 QUEEN'S PLATE DR
# 1742546              150              1719.0   2160 ST CLAIR AVE W
# 1742547              150              1728.0   2287 EGLINTON AVE W
# 1742548               40              1733.0       177 BINGHAM AVE
# 1742549               50              1742.0        99 SCARLETT RD
# 1742550               30              1754.0      120 GERRARD ST E
# 1742551               30              1820.0    54 A BELLWOODS AVE
# 1742552               30              1859.0       14 MOSSFORD CRT
# 1742553               30              1901.0     298 HILLMOUNT AVE
# 1742554               30              1911.0          34 GOUGH AVE
# 1742555               30              1923.0         87 BASTION ST
# 1742556               30              2028.0        29 WINKLER TER
# 1742557               50              2053.0     3816 DANFORTH AVE
# 1742558              150              2128.0        3191 WESTON RD
# 1742559               50              2128.0            26 YORK ST
# 1742560              150              2153.0       126 SENTINEL RD
# 1742561              150              2156.0        71 SENTINEL RD
# 1742562              150              2157.0        71 SENTINEL RD
# 1742563               50              2357.0       282 GILLARD AVE
# 1742564               60              2359.0  40 SPRING GARDEN AVE
#
# [1742565 rows x 6 columns]

# %%
#Create SQL connection
rds_connection_string = "root:root123@127.0.0.1:3306/parking_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
#Check for table
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\_auth.py in caching_sha2_password_auth(conn, pkt)
#     264     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 265     pkt = _roundtrip(conn, data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\_auth.py in _roundtrip(conn, send_data)
#     121     conn.write_packet(send_data)
# --> 122     pkt = conn._read_packet()
#     123     pkt.check_error()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1049, "Unknown database 'parking_db'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-36-61e16a250986> in <module>
#       1 #Check for table
# ----> 2 engine.table_names()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2134         """
#    2135
# -> 2136         with self._optional_conn_ctx_manager(connection) as conn:
#    2137             if not schema:
#    2138                 schema = self.dialect.default_schema_name
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    1930     def _optional_conn_ctx_manager(self, connection=None):
#    1931         if connection is None:
# -> 1932             with self.contextual_connect() as conn:
#    1933                 yield conn
#    1934         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     398         """
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#     402         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     880             # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#     884                 auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\_auth.py in caching_sha2_password_auth(conn, pkt)
#     263
#     264     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 265     pkt = _roundtrip(conn, data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\_auth.py in _roundtrip(conn, send_data)
#     120 def _roundtrip(conn, send_data):
#     121     conn.write_packet(send_data)
# --> 122     pkt = conn._read_packet()
#     123     pkt.check_error()
#     124     return pkt
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1049, "Unknown database 'parking_db'") (Background on this error at: http://sqlalche.me/e/2j85)

# %%
#Export to SQL. If table already exists, data will be appended
merged_df.to_sql(name='parking_tickets', con=engine, if_exists='append', index=True)
